# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\shunn\Downloads\insurance_data.csv")
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
df.tail()
# Out:
#     age  bought_insurance
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
#Seeing which model is suitable
# %matplotlib inline
plt.scatter(df.age,df.bought_insurance)

# %%
#train test split
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(df[['age']],df.bought_insurance,test_size=0.1)

# %%
X_train
# Out:
#     age
# 23   45
# 26   23
# 19   18
# 1    25
# 22   40
# 21   26
# 4    46
# 13   29
# 7    60
# 15   55
# 6    55
# 16   25
# 2    47
# 3    52
# 17   58
# 0    22
# 8    62
# 11   28
# 14   49
# 10   18
# 18   19
# 20   21
# 25   54
# 12   27

# %%
X_test
# Out:
#     age
# 24   50
# 5    56
# 9    61

# %%
#model implementation
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([1, 1, 1], dtype=int64)

# %%
model.score(X_test,y_test)
# Out:
# 1.0

# %%
EXCERCISE

# %%
df=pd.read_csv(r"C:\Users\shunn\Downloads\HR_comma_sep.csv")
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df.shape
# Out:
# (14999, 10)

# %%
subdf=df[['satisfaction_level','average_montly_hours','promotion_last_5years','salary']]

# %%
subdf
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  salary
# 0                    0.38                   157                      0     low
# 1                    0.80                   262                      0  medium
# 2                    0.11                   272                      0  medium
# 3                    0.72                   223                      0     low
# 4                    0.37                   159                      0     low
# ...                   ...                   ...                    ...     ...
# 14994                0.40                   151                      0     low
# 14995                0.37                   160                      0     low
# 14996                0.37                   143                      0     low
# 14997                0.11                   280                      0     low
# 14998                0.37                   158                      0     low
#
# ...

# %%
dummies=pd.get_dummies(subdf.salary,prefix='salary',subdf.astype(int))
dummies
# Out:
#   Cell In[45], line 1
#     dummies=pd.get_dummies(subdf.salary,prefix='salary',subdf.astype(int))
#                                                                          ^
# SyntaxError: positional argument follows keyword argument

# %%
newdf=pd.concat([subdf,dummies],axis="columns")

# %%
newdf
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  \
# 0                    0.38                   157                      0
# 1                    0.80                   262                      0
# 2                    0.11                   272                      0
# 3                    0.72                   223                      0
# 4                    0.37                   159                      0
# ...                   ...                   ...                    ...
# 14994                0.40                   151                      0
# 14995                0.37                   160                      0
# 14996                0.37                   143                      0
# 14997                0.11                   280                      0
# 14998                0.37                   158                      0
#
#        salary  salary_high  salary_low  salary_medium
# 0         low        False        True          False
# ...

# %%
import word2number
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 import word2number
#
# ModuleNotFoundError: No module named 'word2number'

# %%
newdf.drop('salary',axis='columns',inplace=True)

# %%
newdf
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  \
# 0                    0.38                   157                      0
# 1                    0.80                   262                      0
# 2                    0.11                   272                      0
# 3                    0.72                   223                      0
# 4                    0.37                   159                      0
# ...                   ...                   ...                    ...
# 14994                0.40                   151                      0
# 14995                0.37                   160                      0
# 14996                0.37                   143                      0
# 14997                0.11                   280                      0
# 14998                0.37                   158                      0
#
#        salary_high  salary_low  salary_medium
# 0            False        True          False
# ...
