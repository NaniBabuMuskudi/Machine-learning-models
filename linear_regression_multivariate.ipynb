# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv(r"C:\Users\shunn\Downloads\homeprices.csv")
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
df.bedrooms.isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# Name: bedrooms, dtype: bool

# %%
bed_median = df.bedrooms.median()
bed_median
# Out:
# 4.0

# %%
df.bedrooms=df.bedrooms.fillna(bed_median)

# %%
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       4.0   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
ref=linear_model.LinearRegression()
ref.fit(df[['area','bedrooms','age']],df.price)
# Out:
# LinearRegression()

# %%
ref.predict([[2600,3.0,20]])
# Out:
# C:\Users\shunn\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([518217.63297611])

# %%
import word2number as wn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 import word2number as wn
#
# ModuleNotFoundError: No module named 'word2number'

# %%
pip install word2number
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000264B0A16540>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/word2number/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000264B0CDD490>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/word2number/
# ...

# %%
'''EXCERCISE

# %%
import word2number as w2n
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import word2number as w2n
#
# ModuleNotFoundError: No module named 'word2number'

# %%
from word2number import w2n
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from word2number import w2n
#
# ModuleNotFoundError: No module named 'word2number'

# %%
pip install word2number

# %%
#EXCERCISE

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv(r"C:\Users\shunn\Downloads\hiring (1).csv")
df
# Out:
#   experience  test_score  interview_score(out of 10)  salary($)
# 0        NaN         8.0                           9      50000
# 1        NaN         8.0                           6      45000
# 2       five         6.0                           7      60000
# 3        two        10.0                          10      65000
# 4      seven         9.0                           6      70000
# 5      three         7.0                          10      62000
# 6        ten         NaN                           7      72000
# 7     eleven         7.0                           8      80000

# %%
import word2number as w2n

# %%
df.experience=df.experience.fillna('zero')

# %%
df
# Out:
#   experience  test_score  interview_score(out of 10)  salary($)
# 0       zero         8.0                           9      50000
# 1       zero         8.0                           6      45000
# 2       five         6.0                           7      60000
# 3        two        10.0                          10      65000
# 4      seven         9.0                           6      70000
# 5      three         7.0                          10      62000
# 6        ten         NaN                           7      72000
# 7     eleven         7.0                           8      80000

# %%
test_median= df.test_score.median()

# %%
# Out:
#   Cell In[12], line 1
#     df['test_score']=df([test_score(out of 10)])
#                                     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
test_median
# Out:
# 8.0

# %%
df['test_score']=df.test_score.fillna(test_median)

# %%
df
# Out:
#   experience  test_score  interview_score(out of 10)  salary($)
# 0       zero         8.0                           9      50000
# 1       zero         8.0                           6      45000
# 2       five         6.0                           7      60000
# 3        two        10.0                          10      65000
# 4      seven         9.0                           6      70000
# 5      three         7.0                          10      62000
# 6        ten         8.0                           7      72000
# 7     eleven         7.0                           8      80000

# %%
df.experience=df.experience.apply(w2n.word_to_num)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df.experience=df.experience.apply(w2n.word_to_num)
#
# AttributeError: module 'word2number' has no attribute 'word_to_num'

# %%
df.experience = df.experience.apply(w2n.word_to_num)
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 df.experience = df.experience.apply(w2n.word_to_num)
#       2 df
#
# AttributeError: module 'word2number' has no attribute 'word_to_num'

# %%
pip install word2number
