# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\shunn\Downloads\carprices.csv")
df.head()
# Out:
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          31500

# %%
# %matplotlib inline
plt.scatter(df['Age(yrs)'],df['Mileage'])

# %%
X=df[['Mileage','Age(yrs)']]
y=df['Sell Price($)']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=10)

# %%
X_train
# Out:
#     Mileage  Age(yrs)
# 3     22500         2
# 18    87600         8
# 13    58780         4
# 2     57000         5
# 14    82450         7
# 8     91000         8
# 17    69000         5
# 16    28000         2
# 19    52000         5
# 12    59000         5
# 11    79000         7
# 1     35000         3
# 0     69000         6
# 15    25400         3
# 4     46000         4
# 9     67000         6

# %%
X_test
# Out:
#     Mileage  Age(yrs)
# 7     72000         6
# 10    83000         7
# 5     59000         5
# 6     52000         5

# %%
y_train
# Out:
# 3     40000
# 18    12800
# 13    27500
# 2     26100
# 14    19400
# 8     12000
# 17    19700
# 16    35500
# 19    28200
# 12    26000
# 11    19500
# 1     34000
# 0     18000
# 15    35000
# 4     31500
# 9     22000
# Name: Sell Price($), dtype: int64

# %%
y_test
# Out:
# 7     19300
# 10    18700
# 5     26750
# 6     32000
# Name: Sell Price($), dtype: int64

# %%
from sklearn.linear_model import LinearRegression
# Out:
#   Cell In[24], line 1
#     from sklearn.linear_model import LinearRegression()
#                                                      ^
# SyntaxError: invalid syntax

# %%
reg=LinearRegression()

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
reg.predict(X_test)
# Out:
# array([20474.0745775 , 16352.07892168, 25174.14834912, 27197.42175439])

# %%
y_test
# Out:
# 7     19300
# 10    18700
# 5     26750
# 6     32000
# Name: Sell Price($), dtype: int64
